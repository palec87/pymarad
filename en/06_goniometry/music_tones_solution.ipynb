# %% [markdown]
# # Creating a new instrument sound (TODO: code, comments)
# * topics: Music, waves, Fourier transform, trigonometric functions
#
# ## Task
# * Single tone played on the instrument is in principle single frequency wave.
# * How is it possible then, that your ear easily recognizes tone coming from different musical instruments, for example piano and acordeon?
# * I will show you how to play and look at `.wav` files.
# * And we will analyze the tones in time and frequency.
#
# ## Questions
# * Find out diiference which makes instrument sound unique and recognizable from others.
# * Can we create a new instrument which is a mixture of piano and acordeon?

# %% [markdown]
# ---
# ---
# # In case this is your first Jupyter Notebook:
# * Every cell is executed with `Shift-Enter`, once your cursor is in it.
# * After successul run, a serial number of the execution will appear on the left from the cell
# * For cell execution and creation of a new cell below, use `Alt-Enter`.
# * Any text after a # symbol is a comment (to annotate your code) and it is ignored by Python
# * Caution: If you execute a cell which has a hint in the output, the hint will disappear, therefore it is better to use `Alt-Enter`.
# ---
# ---

# %%
from scipy.io import wavfile  # load properly wav files
import matplotlib.pyplot as plt  # plotting
import numpy as np  ## numerical python to work with the waves data
import IPython  # to include more interactiveness to Notebook, such as playing wav files

# %% [markdown]
# Let's inspect the first wav file

# %%
file = 'acordeon01.wav'
IPython.display.Audio(file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
samplerate, data = wavfile.read(file)
# print(f"number of channels = {data.shape[1]}")

length = data.shape[0] / samplerate
print(f"length = {length}s")
# Out:
# length = 1.6248979591836734s
# C:\Users\David Palecek\Documents\Python_projects\pymarad\lib\site-packages\ipykernel_launcher.py:1: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   """Entry point for launching an IPython kernel.

# %%
len(data)
# Out:
# 71658

# %%
time = np.linspace(0., length, data.shape[0])
const = 6000
plt.plot(time[:const], data[:const])
plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data
# Out:
# array([    0,     0,    -1, ..., -4851, -2891,  -363], dtype=int16)

# %%
data.shape
# Out:
# (71658,)
