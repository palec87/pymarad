# %% [markdown]
# # Emptiness of the world
#     * author reference: David Palecek (ddthumb@gmail.com)
#   Topics: Percentages, unit conversions, Avogadro constant, Van der Walls/covalent radius of atoms,
#
# ## Task
#
#   * If you search the internet, standard answer to 'how big of a volume does a water molecule hold' goes like this:
#     * calculate total number of molecules in 1 liter
#     * divide volume of 1 liter (1 dm<sup>3</sup>) by number of molecules
#     * you get volume of one H<sub>2</sub>O
#
#   * The above way of thinking hides from you some amazing facts, which are the topic of this project.
#
# ## Question
# 1. Understand difference between Van der Waals and covalent radius of an atom.
# 2. Calculate volume based on those radii and compare them to standard chemistry class calculation.
# 3. How much empty space (in percents) do you find in the water volume?
#
# Note: There is a another water/chemistry project 'Pee in the sea' in the Probability section, using Avogadro constant, and more. Check it out for more amazing water facts.

# %%
# In color is shown Van der Vaals volume, and shaded space inside is the covalent extend of electron cloud.
# I tried to keep the water molecule approximately in scale.
from IPython.display import Image
Image('https://raw.githubusercontent.com/palec87/pymarad/main/resource/fig/h2o_molecule.png', retina=True)

# %% [markdown]
# Van der Waals radius gives us distance, when the neigboring water molecule (mainly electrons) will feel so much repulsion, that the molecules cannot get any closer to each other
#   * Imagine two magnets repulsing each other
#   * Or the Earth and the Sun, there is an interaction between the two objects in both cases, however also lots of empty space.
#   * And Van der Waals volume includes that empty space, because it cares about the interaction.
#
# ---
#
# ## Now, if we consider only how far nucleus and electrons extend, what percentage of water volume is empty space?

# %%
import scipy.constants as const
import numpy as np

# %%
# moles in 1 liter (weight divided by molecular weight (in g/mol), which is sum of atomic weights)
moles_per_liter = 

## and multiply by Avogadro constant, which is amount of particles in 1 mole.
molecules_water =

# %% [markdown]
# ### Let's start with the Van der Waals volume
# We sum the volumes of spheres of the three atoms forming a water molecule,
#
# where volume of a sphere is $\mathrm{V=\dfrac{4}{3}\pi r^3}$.

# %%
# Van der Waals (vdw)
rh_vdw = 120e-12  # radius of hydrogen atom in m
ro_vdw = 152e-12  # radius of oxygen atom in m

# volume of h2o molecules in m3, taking atoms as balls
v_h2o_vdw = 

# 1 liter is 1dm3, and conversion factor from m3 to dm3 is 1000=1e3
volume_liter_vdw = molecules_water * v_h2o_vdw * 1e3
print('Volume of 1 liter (we expect 1 dm3): ', round(volume_liter_vdw,3))
# Out:
# Volume of 1 liter (we expect 1 dm3):  0.975

# %%
# We convert it to percents by multiplying by 100.
# Out:
# In percents: 97.5

# %% [markdown]
# * This means we explained almost 98% of the water volume, VdW therefore nicely describes some kind of effective volume of water molecule.
# * Getting closer is for the H<sub>2</sub>O molecules almost impossible because of their electron repulsion.
#
# ---
#
# ### Now we do covalent radius, which is the physical extend of protons, neutrons and electrons in the space.

# %%
# covalent radius
# https://en.wikipedia.org/wiki/Covalent_radius
# https://en.wikipedia.org/wiki/Atomic_radii_of_the_elements_(data_page)
# much smaller than Van der waals
# in m
rh = 32e-12
ro = 63e-12

# volume of h2o molecule in m3
v_h2o = 

# 1 liter is 1dm3 so conversion factor from m3 to dm3 is 1000=1e3
volume_liter = molecules_water * v_h2o * 1e3
print('Volume of 1 liter (we expect 1 dm3): ', round(volume_liter,3))
# Out:
# Volume of 1 liter (we expect 1 dm3):  0.044

# %%
# print in percents
# Out:
# In percents: 4.4

# %% [markdown]
# This means one single amazing thing:
#
# ## At least 95% of the space inside the water is totally empty!!!
#   * Note that we made radius of Hydrogen smaller only ~4x and Oxygen ~2.5x, respectively.
#   * The reason it leads to 95% shrinking is the third power in the *volume* calculation.
#
# ---
#
# ## If you think this is some special case for water or liquids, try to figure out the same for a brick of pure gold.

# %%
# constants you need
m_au = 197          # in g/mol
density_au = 19.3   # g/cm3
r_au = 124e-12      # in m

# we take 1 cm3 of gold
n_atoms_au = 
vol_atoms = 
print('Volume of gold atoms (expecting 1cm3): ', round(vol_atoms,3))
# Out:
# Volume of gold atoms (expecting 1cm3):  0.471

# %%
# print in percents
# Out:
# In percents: 47.1

# %% [markdown]
# ## Gold is 'only' 53% empty!
#
# ---
#
# ## Conclusion:
#   * We do not see it, but the matter around us is mostly very holy.
#   * Typical calculations you encounter ignore it, and calculate effective (Van der Waals) volumes.
#   * It makes sense however, because we cannot take advantage of that space, due to the strong interaction forces within the Van der Waals volume.
#
# ## Questions:
#   * There is even more empty space, since atoms themselves are formed by electrons, protons and neutrons which can be assigned some sort of volume too.
#     * Can you calculate percentage of empty volume within H and O atoms?
#   * If you have done the above, what is the total empty space within the water, given the matter is only protons, neutrons and electrons?
#
# # Good Job!
